# %%
import os
os.chdir("../..")

import torch
from torchvision import transforms

import cv2
import numpy as np
from PIL import Image
from matplotlib import pyplot as plt

import tensorflow as tf

from languagebind import LanguageBind, to_device, transform_dict, LanguageBindImageTokenizer

from xplique.wrappers import TorchWrapper
from xplique.plots import plot_attributions
from xplique.attributions import (Saliency, GradientInput, IntegratedGradients, SmoothGrad, VarGrad,
                                  SquareGrad, Occlusion, Rise, GuidedBackprop, Lime, KernelShap, SobolAttributionMethod, HsicAttributionMethod)
# Out:
# 2024-06-26 14:59:54.465999: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-06-26 14:59:54.515903: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-26 14:59:55.485013: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /home/cry/anaconda3/envs/hsic/lib/python3.8/site-packages/torchvision/transforms/_functional_video.py:6: UserWarning: The 'torchvision.transforms._functional_video' module is deprecated since 0.12 and will be removed in the future. Please use the 'torchvision.transforms.functional' module instead.
#   warnings.warn(
# /home/cry/anaconda3/envs/hsic/lib/python3.8/site-packages/torchvision/transforms/_transforms_video.py:22: UserWarning: The 'torchvision.transforms._transforms_video' module is deprecated since 0.12 and will be removed in the future. Please use the 'torchvision.transforms' module instead.
#   warnings.warn(

# %%
tf.config.run_functions_eagerly(True)

gpus = tf.config.experimental.list_physical_devices(device_type='GPU')
tf.config.experimental.set_virtual_device_configuration(
    gpus[0],
    [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=2048)]
)

# %%
class LanguageBindModel_Super(torch.nn.Module):
    def __init__(self, base_model, device,
                 pretrained_ckpt = f'lb203/LanguageBind_Image',):
        super().__init__()
        self.base_model = base_model
        self.device = device
        self.tokenizer = LanguageBindImageTokenizer.from_pretrained(
            pretrained_ckpt, cache_dir='.checkpoints/tokenizer_cache_dir')
        
        self.clip_type = ["video", "audio", "thermal", "image", "depth"]
        self.modality_transform = {c: transform_dict[c](self.base_model.modality_config[c]) for c in self.clip_type}
    
    def mode_selection(self, mode):
        if mode not in ["image", "audio", "video", "depth", "thermal", "language"]:
            print("mode {} does not comply with the specification, please select from \"image\", \"audio\", \"video\", \"depth\", \"thermal\", \"language\".".format(mode))
        else:
            self.mode = mode
            print("Select mode {}".format(mode))
    
    def equip_semantic_modal(self, modal_list):
        if self.mode == "language":
            self.semantic_modal = to_device(self.tokenizer(modal_list, max_length=77, padding='max_length',
                                             truncation=True, return_tensors='pt'), self.device)
        elif self.mode in self.clip_type:
            self.semantic_modal = to_device(self.modality_transform[self.mode](modal_list), self.device)
        
        input = {
                # "vision": vision_inputs,
                self.mode: self.semantic_modal
            }
        with torch.no_grad():
            self.semantic_modal = self.base_model(input)[self.mode]
        print("Equip with {} modal.".format(self.mode))
    
    def forward(self, vision_inputs):
        """
        Input:
            vision_inputs: 
        """
        inputs = {
            "image": {'pixel_values': vision_inputs},
        }
        
        with torch.no_grad():
            embeddings = self.base_model(inputs)
            
        scores = torch.softmax(embeddings["image"] @ self.semantic_modal.T, dim=-1)
        return scores

# %%
def load_and_transform_vision_data(image_paths, device, channel_first=False):
    if image_paths is None:
        return None

    image_outputs = []

    data_transform = transforms.Compose(
        [
            transforms.Resize(
                (224,224), interpolation=transforms.InterpolationMode.BICUBIC
            ),
            # transforms.CenterCrop(224),
            transforms.ToTensor(),
            transforms.Normalize(
                mean=(0.48145466, 0.4578275, 0.40821073),
                std=(0.26862954, 0.26130258, 0.27577711),
            ),
        ]
    )
    
    for image_path in image_paths:
        with open(image_path, "rb") as fopen:
            image = Image.open(fopen).convert("RGB")

        image = data_transform(image).to(device)
        image_outputs.append(image)
    image_outputs = torch.stack(image_outputs, dim=0)
    if channel_first:
        pass
    else:
        image_outputs = image_outputs.permute(0,2,3,1)
    return image_outputs.cpu().numpy()

# %%
text_list=["A dog.", "A car.", "A bird.", "An airplane.", "A bicycle.", "A boat.", "A cat.", "A chair", "A cow.", "A diningtable.", "A horse.", "A motorbike.", "A person.", "A pottedplant.", "A sheep.", "A sofa.", "A train.", "A tvmonitor."]
image_paths=[".assets/dog_image.jpg", ".assets/car_image.jpg", ".assets/bird_image.jpg"]

# %%
device = "cuda:1" if torch.cuda.is_available() else "cpu"
# LanguageBind model
clip_type = {
    'video': 'LanguageBind_Video_FT',  # also LanguageBind_Video
    'audio': 'LanguageBind_Audio_FT',  # also LanguageBind_Audio
    'thermal': 'LanguageBind_Thermal',
    'image': 'LanguageBind_Image',
    'depth': 'LanguageBind_Depth',
}
model = LanguageBind(clip_type=clip_type, cache_dir='.checkpoints')
model = model.to(device)
model.eval()

pretrained_ckpt = f'lb203/LanguageBind_Image'
lang_model = LanguageBindModel_Super(model, device, pretrained_ckpt)
print("ok")
# Out:
# Some weights of the model checkpoint at LanguageBind/LanguageBind_Thermal were not used when initializing LanguageBindThermal: ['vision_model.encoder.base_model.model.layers.0.self_attn.out_proj.weight', 'vision_model.encoder.base_model.model.layers.15.self_attn.q_proj.bias', 'vision_model.encoder.base_model.model.layers.2.self_attn.k_proj.weight', 'vision_model.encoder.base_model.model.layers.18.self_attn.q_proj.bias', 'vision_model.encoder.base_model.model.layers.7.self_attn.v_proj.bias', 'vision_model.encoder.base_model.model.layers.6.self_attn.k_proj.weight', 'vision_model.encoder.base_model.model.layers.21.self_attn.v_proj.bias', 'vision_model.encoder.base_model.model.layers.17.self_attn.v_proj.bias', 'vision_model.encoder.base_model.model.layers.0.self_attn.q_proj.bias', 'vision_model.encoder.base_model.model.layers.2.self_attn.v_proj.bias', 'vision_model.encoder.base_model.model.layers.3.self_attn.v_proj.weight', 'vision_model.encoder.base_model.model.layers.2.self_attn.v_proj.weight', 'vision_model.encoder.base_model.model.layers.20.self_attn.k_proj.bias', 'vision_model.encoder.base_model.model.layers.6.self_attn.v_proj.weight', 'vision_model.encoder.base_model.model.layers.14.self_attn.k_proj.weight', 'vision_model.encoder.base_model.model.layers.0.self_attn.k_proj.bias', 'vision_model.encoder.base_model.model.layers.17.self_attn.v_proj.weight', 'vision_model.encoder.base_model.model.layers.2.self_attn.k_proj.bias', 'vision_model.encoder.base_model.model.layers.12.self_attn.v_proj.bias', 'vision_model.encoder.base_model.model.layers.16.self_attn.q_proj.weight', 'vision_model.encoder.base_model.model.layers.15.self_attn.k_proj.bias', 'vision_model.encoder.base_model.model.layers.3.self_attn.out_proj.weight', 'vision_model.encoder.base_model.model.layers.13.self_attn.q_proj.weight', 'vision_model.encoder.base_model.model.layers.2.self_attn.out_proj.bias', 'vision_model.encoder.base_model.model.layers.0.self_attn.out_proj.bias', 'vision_model.encoder.base_model.model.layers.4.self_attn.v_proj.weight', 'vision_model.encoder.base_model.model.layers.10.self_attn.k_proj.bias', 'vision_model.encoder.base_model.model.layers.0.self_attn.k_proj.weight', 'vision_model.encoder.base_model.model.layers.19.self_attn.out_proj.weight', 'vision_model.encoder.base_model.model.layers.21.self_attn.k_proj.weight', 'vision_model.encoder.base_model.model.layers.11.self_attn.v_proj.bias', 'vision_model.encoder.base_model.model.layers.23.self_attn.v_proj.bias', 'vision_model.encoder.base_model.model.layers.11.self_attn.v_proj.weight', 'vision_model.encoder.base_model.model.layers.17.self_attn.q_proj.weight', 'vision_model.encoder.base_model.model.layers.14.self_attn.out_proj.weight', 'vision_model.encoder.base_model.model.layers.22.self_attn.q_proj.weight', 'vision_model.encoder.base_model.model.layers.2.self_attn.q_proj.weight', 'vision_model.encoder.base_model.model.layers.12.self_attn.q_proj.bias', 'vision_model.encoder.base_model.model.layers.10.self_attn.k_proj.weight', 'vision_model.encoder.base_model.model.layers.17.self_attn.k_proj.bias', 'vision_model.encoder.base_model.model.layers.21.self_attn.v_proj.weight', 'vision_model.encoder.base_model.model.layers.5.self_attn.out_proj.bias', 'vision_model.encoder.base_model.model.layers.5.self_attn.q_proj.weight', 'vision_model.encoder.base_model.model.layers.5.self_attn.out_proj.weight', 'vision_model.encoder.base_model.model.layers.4.self_attn.q_proj.weight', 'vision_model.encoder.base_model.model.layers.10.self_attn.q_proj.weight', 'vision_model.encoder.base_model.model.layers.0.self_attn.v_proj.weight', 'vision_model.encoder.base_model.model.layers.13.self_attn.out_proj.weight', 'vision_model.encoder.base_model.model.layers.16.self_attn.out_proj.bias', 'vision_model.encoder.base_model.model.layers.11.self_attn.q_proj.weight', 'vision_model.encoder.base_model.model.layers.19.self_attn.k_proj.weight', 'vision_model.encoder.base_model.model.layers.11.self_attn.k_proj.bias', 'vision_model.enco ...
# - This IS expected if you are initializing LanguageBindThermal from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing LanguageBindThermal from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of LanguageBindThermal were not initialized from the model checkpoint at LanguageBind/LanguageBind_Thermal and are newly initialized: ['vision_model.encoder.base_model.model.layers.11.self_attn.out_proj.base_layer.weight', 'vision_model.encoder.base_model.model.layers.0.self_attn.out_proj.base_layer.bias', 'vision_model.encoder.base_model.model.layers.5.self_attn.q_proj.base_layer.weight', 'vision_model.encoder.base_model.model.layers.2.self_attn.v_proj.base_layer.bias', 'vision_model.encoder.base_model.model.layers.9.self_attn.k_proj.base_layer.weight', 'vision_model.encoder.base_model.model.layers.11.self_attn.q_proj.base_layer.bias', 'vision_model.encoder.base_model.model.layers.15.self_attn.out_proj.base_layer.bias', 'vision_model.encoder.base_model.model.layers.20.self_attn.out_proj.base_layer.bias', 'vision_model.encoder.base_model.model.layers.17.self_attn.k_proj.base_layer.bias', 'vision_model.encoder.base_model.model.layers.14.self_attn.v_proj.base_layer.bias', 'vision_model.encoder.base_model.model.layers.5.self_attn.v_proj.base_layer.weight', 'vision_model.encoder.base_model.model.layers.12.self_attn.q_proj.base_layer.bias', 'vision_model.encoder.base_model.model.layers.13.self_attn.out_proj.base_layer.bias', 'vision_model.encoder.base_model.model.layers.1.self_attn.q_proj.base_layer.weight', 'vision_model.encoder.base_model.model.layers.6.self_attn.out_proj.base_layer.bias', 'vision_model.encoder.base_model.model.layers.3.self_attn.k_proj.base_layer.weight', 'vision_model.encoder.base_model.model.layers.14.self_attn.out_proj.base_layer.bias', 'vision_model.encoder.base_model.model.layers.1.self_attn.q_proj.base_layer.bias', 'vision_model.encoder.base_model.model.layers.5.self_attn.out_proj.base_layer.weight', 'vision_model.encoder.base_model.model.layers.21.self_attn.k_proj.base_layer.weight', 'vision_model.encoder.base_model.model.layers.9.self_attn.out_proj.base_layer.weight', 'vision_model.encoder.base_model.model.layers.1.self_attn.v_proj.base_layer.weight', 'vision_model.encoder.base_model.model.layers.16.self_attn.v_proj.base_layer.weight', 'vision_model.encoder.base_model.model.layers.12.self_attn.v_proj.base_layer.bias', 'vision_model.encoder.base_model.model.layers.19.self_attn.out_proj.base_layer.bias', 'vision_model.encoder.base_model.model.layers.2.self_attn.q_proj.base_layer.weight', 'vision_model.encoder.base_model.model.layers.23.self_attn.out_proj.base_layer.weight', 'vision_model.encoder.base_model.model.layers.14.self_attn.k_proj.base_layer.weight', 'vision_model.encoder.base_model.model.layers.6.self_attn.k_proj.base_layer.weight', 'vision_model.encoder.base_model.model.layers.3.self_attn.v_proj.base_layer.bias', 'vision_model.encoder.base_model.model.layers.17.self_attn.q_proj.base_layer.weight', 'vision_model.encoder.base_model.model.layers.5.self_attn.out_proj.base_layer.bias', 'vision_model.encoder.base_model.model.layers.4.self_attn.q_proj.base_layer.weight', 'vision_model.encoder.base_model.model.layers.22.self_attn.out_proj.base_layer.bias', 'vision_model.encoder.base_model.model.layers.22.self_attn.q_proj.base_layer.weight', 'vision_model.encoder.base_model.model.layers.17.self_attn.v_proj.base_layer.weight', 'vision_model.encoder.base_model.model.layers.18.self_attn.out_proj.base_layer.bias', 'vision_model.encoder.base_model.model.layers.6.self_attn.q_proj.base_layer.weight', 'vision_model.encoder.base_model.model.layers.4.self_attn.k_proj.base_layer.weight', 'vision_model.encoder.base_model.model.layers.18.self_attn.v_proj.base_layer.weight', 'vision_model.encoder.base_model.model.layers.8.self_attn.out_proj.base_layer.bias', 'vision_model.encoder.base_model.model.layers.20.self_attn.out_proj.base_layer.weight', 'vision_model.encoder.base_model.model.layers.19.self_attn.v_proj.base_layer.bias', 'vision_model.encoder.base_model.model.layers.17.self_attn.out_proj.base_layer.bias', 'vision_model.encoder.base_model.model.layers.22.self_attn.q_proj.base_layer.bias', 'vision_mode ...
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of the model checkpoint at LanguageBind/LanguageBind_Depth were not used when initializing LanguageBindDepth: ['vision_model.encoder.base_model.model.layers.0.self_attn.out_proj.weight', 'vision_model.encoder.base_model.model.layers.15.self_attn.q_proj.bias', 'vision_model.encoder.base_model.model.layers.2.self_attn.k_proj.weight', 'vision_model.encoder.base_model.model.layers.18.self_attn.q_proj.bias', 'vision_model.encoder.base_model.model.layers.7.self_attn.v_proj.bias', 'vision_model.encoder.base_model.model.layers.6.self_attn.k_proj.weight', 'vision_model.encoder.base_model.model.layers.21.self_attn.v_proj.bias', 'vision_model.encoder.base_model.model.layers.17.self_attn.v_proj.bias', 'vision_model.encoder.base_model.model.layers.0.self_attn.q_proj.bias', 'vision_model.encoder.base_model.model.layers.2.self_attn.v_proj.bias', 'vision_model.encoder.base_model.model.layers.3.self_attn.v_proj.weight', 'vision_model.encoder.base_model.model.layers.2.self_attn.v_proj.weight', 'vision_model.encoder.base_model.model.layers.20.self_attn.k_proj.bias', 'vision_model.encoder.base_model.model.layers.6.self_attn.v_proj.weight', 'vision_model.encoder.base_model.model.layers.14.self_attn.k_proj.weight', 'vision_model.encoder.base_model.model.layers.0.self_attn.k_proj.bias', 'vision_model.encoder.base_model.model.layers.17.self_attn.v_proj.weight', 'vision_model.encoder.base_model.model.layers.2.self_attn.k_proj.bias', 'vision_model.encoder.base_model.model.layers.12.self_attn.v_proj.bias', 'vision_model.encoder.base_model.model.layers.16.self_attn.q_proj.weight', 'vision_model.encoder.base_model.model.layers.15.self_attn.k_proj.bias', 'vision_model.encoder.base_model.model.layers.3.self_attn.out_proj.weight', 'vision_model.encoder.base_model.model.layers.13.self_attn.q_proj.weight', 'vision_model.encoder.base_model.model.layers.2.self_attn.out_proj.bias', 'vision_model.encoder.base_model.model.layers.0.self_attn.out_proj.bias', 'vision_model.encoder.base_model.model.layers.4.self_attn.v_proj.weight', 'vision_model.encoder.base_model.model.layers.10.self_attn.k_proj.bias', 'vision_model.encoder.base_model.model.layers.0.self_attn.k_proj.weight', 'vision_model.encoder.base_model.model.layers.19.self_attn.out_proj.weight', 'vision_model.encoder.base_model.model.layers.21.self_attn.k_proj.weight', 'vision_model.encoder.base_model.model.layers.11.self_attn.v_proj.bias', 'vision_model.encoder.base_model.model.layers.23.self_attn.v_proj.bias', 'vision_model.encoder.base_model.model.layers.11.self_attn.v_proj.weight', 'vision_model.encoder.base_model.model.layers.17.self_attn.q_proj.weight', 'vision_model.encoder.base_model.model.layers.14.self_attn.out_proj.weight', 'vision_model.encoder.base_model.model.layers.22.self_attn.q_proj.weight', 'vision_model.encoder.base_model.model.layers.2.self_attn.q_proj.weight', 'vision_model.encoder.base_model.model.layers.12.self_attn.q_proj.bias', 'vision_model.encoder.base_model.model.layers.10.self_attn.k_proj.weight', 'vision_model.encoder.base_model.model.layers.17.self_attn.k_proj.bias', 'vision_model.encoder.base_model.model.layers.21.self_attn.v_proj.weight', 'vision_model.encoder.base_model.model.layers.5.self_attn.out_proj.bias', 'vision_model.encoder.base_model.model.layers.5.self_attn.q_proj.weight', 'vision_model.encoder.base_model.model.layers.5.self_attn.out_proj.weight', 'vision_model.encoder.base_model.model.layers.4.self_attn.q_proj.weight', 'vision_model.encoder.base_model.model.layers.10.self_attn.q_proj.weight', 'vision_model.encoder.base_model.model.layers.0.self_attn.v_proj.weight', 'vision_model.encoder.base_model.model.layers.13.self_attn.out_proj.weight', 'vision_model.encoder.base_model.model.layers.16.self_attn.out_proj.bias', 'vision_model.encoder.base_model.model.layers.11.self_attn.q_proj.weight', 'vision_model.encoder.base_model.model.layers.19.self_attn.k_proj.weight', 'vision_model.encoder.base_model.model.layers.11.self_attn.k_proj.bias', 'vision_model.encoder. ...
# - This IS expected if you are initializing LanguageBindDepth from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing LanguageBindDepth from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of LanguageBindDepth were not initialized from the model checkpoint at LanguageBind/LanguageBind_Depth and are newly initialized: ['vision_model.encoder.base_model.model.layers.11.self_attn.out_proj.base_layer.weight', 'vision_model.encoder.base_model.model.layers.0.self_attn.out_proj.base_layer.bias', 'vision_model.encoder.base_model.model.layers.5.self_attn.q_proj.base_layer.weight', 'vision_model.encoder.base_model.model.layers.2.self_attn.v_proj.base_layer.bias', 'vision_model.encoder.base_model.model.layers.9.self_attn.k_proj.base_layer.weight', 'vision_model.encoder.base_model.model.layers.11.self_attn.q_proj.base_layer.bias', 'vision_model.encoder.base_model.model.layers.15.self_attn.out_proj.base_layer.bias', 'vision_model.encoder.base_model.model.layers.20.self_attn.out_proj.base_layer.bias', 'vision_model.encoder.base_model.model.layers.17.self_attn.k_proj.base_layer.bias', 'vision_model.encoder.base_model.model.layers.14.self_attn.v_proj.base_layer.bias', 'vision_model.encoder.base_model.model.layers.5.self_attn.v_proj.base_layer.weight', 'vision_model.encoder.base_model.model.layers.12.self_attn.q_proj.base_layer.bias', 'vision_model.encoder.base_model.model.layers.13.self_attn.out_proj.base_layer.bias', 'vision_model.encoder.base_model.model.layers.1.self_attn.q_proj.base_layer.weight', 'vision_model.encoder.base_model.model.layers.6.self_attn.out_proj.base_layer.bias', 'vision_model.encoder.base_model.model.layers.3.self_attn.k_proj.base_layer.weight', 'vision_model.encoder.base_model.model.layers.14.self_attn.out_proj.base_layer.bias', 'vision_model.encoder.base_model.model.layers.1.self_attn.q_proj.base_layer.bias', 'vision_model.encoder.base_model.model.layers.5.self_attn.out_proj.base_layer.weight', 'vision_model.encoder.base_model.model.layers.21.self_attn.k_proj.base_layer.weight', 'vision_model.encoder.base_model.model.layers.9.self_attn.out_proj.base_layer.weight', 'vision_model.encoder.base_model.model.layers.1.self_attn.v_proj.base_layer.weight', 'vision_model.encoder.base_model.model.layers.16.self_attn.v_proj.base_layer.weight', 'vision_model.encoder.base_model.model.layers.12.self_attn.v_proj.base_layer.bias', 'vision_model.encoder.base_model.model.layers.19.self_attn.out_proj.base_layer.bias', 'vision_model.encoder.base_model.model.layers.2.self_attn.q_proj.base_layer.weight', 'vision_model.encoder.base_model.model.layers.23.self_attn.out_proj.base_layer.weight', 'vision_model.encoder.base_model.model.layers.14.self_attn.k_proj.base_layer.weight', 'vision_model.encoder.base_model.model.layers.6.self_attn.k_proj.base_layer.weight', 'vision_model.encoder.base_model.model.layers.3.self_attn.v_proj.base_layer.bias', 'vision_model.encoder.base_model.model.layers.17.self_attn.q_proj.base_layer.weight', 'vision_model.encoder.base_model.model.layers.5.self_attn.out_proj.base_layer.bias', 'vision_model.encoder.base_model.model.layers.4.self_attn.q_proj.base_layer.weight', 'vision_model.encoder.base_model.model.layers.22.self_attn.out_proj.base_layer.bias', 'vision_model.encoder.base_model.model.layers.22.self_attn.q_proj.base_layer.weight', 'vision_model.encoder.base_model.model.layers.17.self_attn.v_proj.base_layer.weight', 'vision_model.encoder.base_model.model.layers.18.self_attn.out_proj.base_layer.bias', 'vision_model.encoder.base_model.model.layers.6.self_attn.q_proj.base_layer.weight', 'vision_model.encoder.base_model.model.layers.4.self_attn.k_proj.base_layer.weight', 'vision_model.encoder.base_model.model.layers.18.self_attn.v_proj.base_layer.weight', 'vision_model.encoder.base_model.model.layers.8.self_attn.out_proj.base_layer.bias', 'vision_model.encoder.base_model.model.layers.20.self_attn.out_proj.base_layer.weight', 'vision_model.encoder.base_model.model.layers.19.self_attn.v_proj.base_layer.bias', 'vision_model.encoder.base_model.model.layers.17.self_attn.out_proj.base_layer.bias', 'vision_model.encoder.base_model.model.layers.22.self_attn.q_proj.base_layer.bias', 'vision_model.en ...
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ok

# %%
lang_model.base_model.modality_encoder.video.encoder.layers[-1].layer_norm1
# Out:
# LayerNorm((1024,), eps=1e-05, elementwise_affine=True)

# %%
lang_model.mode_selection("language")
lang_model.equip_semantic_modal(text_list)
# Out:
# Select mode language
# Equip with language modal.

# %%
image_input = load_and_transform_vision_data(image_paths, device)

# %%
image_input.shape
# Out:
# (3, 224, 224, 3)

# %%
vision_input = load_and_transform_vision_data(image_paths, device, channel_first=True)
predict_score = lang_model(torch.from_numpy(vision_input).to(device),
)

# %%
X = [cv2.resize(cv2.imread(image_path), (224,224))[..., ::-1] for image_path in image_paths]
# one-hot
Y = np.eye(predict_score.shape[-1])[predict_score.argmax(-1).cpu().numpy()]

# %%
wrapped_model = TorchWrapper(lang_model.eval(), device)
# Out:
# 2024-04-07 17:47:00.284948: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2048 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:17:00.0, compute capability: 8.6
# 2024-04-07 17:47:00.286121: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 21225 MB memory:  -> device: 1, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:b3:00.0, compute capability: 8.6
# /home/cry/anaconda3/envs/hsic/lib/python3.8/site-packages/xplique/wrappers/pytorch.py:61: UserWarning: TF is set to run eagerly to avoid conflict with PyTorch. Thus,                       TF functions might be slower
#   warnings.warn("TF is set to run eagerly to avoid conflict with PyTorch. Thus,\

# %%
image_input.shape
# Out:
# (3, 224, 224, 3)

# %%
# set batch size parameter
batch_size = 16

# build the explainers
explainers = [
            #  Saliency(wrapped_model),
            #  GradientInput(wrapped_model),
            #  IntegratedGradients(wrapped_model, steps=80, batch_size=batch_size),
            #  SmoothGrad(wrapped_model, nb_samples=80, batch_size=batch_size),
            #  SquareGrad(wrapped_model, nb_samples=80, batch_size=batch_size),
            #  VarGrad(wrapped_model, nb_samples=80, batch_size=batch_size),
             Occlusion(wrapped_model, patch_size=10, patch_stride=5, batch_size=batch_size),
             Rise(wrapped_model, nb_samples=4000, batch_size=batch_size),
             SobolAttributionMethod(wrapped_model, batch_size=batch_size),
             HsicAttributionMethod(wrapped_model, batch_size=batch_size),
             Lime(wrapped_model, nb_samples = 4000, batch_size=batch_size),
             KernelShap(wrapped_model, nb_samples = 4000, batch_size=batch_size)
]

for explainer in explainers:

  explanations = explainer(image_input, Y)

  print(f"Method: {explainer.__class__.__name__}")
  plot_attributions(explanations, X, img_size=2., cmap='jet', alpha=0.4,
                    cols=len(X), absolute_value=True, clip_percentile=0.5)
  plt.show()
  print("\n")
# Out:
# 2024-04-07 17:47:09.517423: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_1' with dtype float and shape [3,18]
# 	 [[{{node Placeholder/_1}}]]
# /home/cry/anaconda3/envs/hsic/lib/python3.8/site-packages/xplique/wrappers/pytorch.py:141: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:199.)
#   torch_inputs = self.torch.Tensor(np_inputs)
# 2024-04-07 17:47:09.623191: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype bool and shape [1849,224,224]
# 	 [[{{node Placeholder/_0}}]]
# 2024-04-07 17:47:32.008510: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype bool and shape [1849,224,224]
# 	 [[{{node Placeholder/_0}}]]
# 2024-04-07 17:47:55.118955: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype bool and shape [1849,224,224]
# 	 [[{{node Placeholder/_0}}]]
# Method: Occlusion
# 2024-04-07 17:48:20.236682: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype bool and shape [4000,7,7,1]
# 	 [[{{node Placeholder/_0}}]]
# 2024-04-07 17:49:11.587337: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype bool and shape [4000,7,7,1]
# 	 [[{{node Placeholder/_0}}]]
# 2024-04-07 17:50:02.269023: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype bool and shape [4000,7,7,1]
# 	 [[{{node Placeholder/_0}}]]
# Method: Rise
# 2024-04-07 17:50:52.702381: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype float and shape [2112,8,8,1]
# 	 [[{{node Placeholder/_0}}]]
# 2024-04-07 17:51:18.892283: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype float and shape [2112,8,8,1]
# 	 [[{{node Placeholder/_0}}]]
# 2024-04-07 17:51:44.949300: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype float and shape [2112,8,8,1]
# 	 [[{{node Placeholder/_0}}]]
# Method: SobolAttributionMethod
# 2024-04-07 17:52:11.236325: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype float and shape [500,8,8,1]
# 	 [[{{node Placeholder/_0}}]]
# 2024-04-07 17:52:17.437772: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_1' with dtype float and shape [64,1,1,500]
# 	 [[{{node Placeholder/_1}}]]
# 2024-04-07 17:52:17.457564: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:637] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2024-04-07 17:52:17.470673: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype float and shape [500,8,8,1]
# 	 [[{{node Placeholder/_0}}]]
# 2024-04-07 17:52:23.644489: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_1' with dtype float and shape [64,1,1,500]
# 	 [[{{node Placeholder/_1}}]]
# 2024-04-07 17:52:23.655934: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype float and shape [500,8,8,1]
# 	 [[{{node Placeholder/_0}}]]
# Method: HsicAttributionMethod
# 2024-04-07 17:52:29.858047: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_1' with dtype float and shape [64,1,1,500]
# 	 [[{{node Placeholder/_1}}]]
# 2024-04-07 17:52:30.061003: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_1' with dtype float and shape [3,18]
# 	 [[{{node Placeholder/_1}}]]
# 2024-04-07 17:52:30.244370: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32 and shape [4000,753]
# 	 [[{{node Placeholder/_0}}]]
# 2024-04-07 17:53:22.729049: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32 and shape [4000,1389]
# 	 [[{{node Placeholder/_0}}]]
# 2024-04-07 17:54:15.151667: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32 and shape [4000,1271]
# 	 [[{{node Placeholder/_0}}]]
# Method: Lime
# 2024-04-07 17:55:52.206611: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_1' with dtype float and shape [3,18]
# 	 [[{{node Placeholder/_1}}]]
# 2024-04-07 17:55:52.399879: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32 and shape [4000,753]
# 	 [[{{node Placeholder/_0}}]]
# 2024-04-07 17:56:44.340208: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32 and shape [4000,1389]
# 	 [[{{node Placeholder/_0}}]]
# 2024-04-07 17:57:37.265500: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32 and shape [4000,1271]
# 	 [[{{node Placeholder/_0}}]]
# Method: KernelShap
